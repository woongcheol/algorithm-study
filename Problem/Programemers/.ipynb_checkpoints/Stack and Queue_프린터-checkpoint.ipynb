# %% [markdown]
# # Programmers 프린터 문제

# %% [markdown]
# ### 문제 설명
# 일반적인 프린터는 인쇄 요청이 들어온 순서대로 인쇄합니다. 그렇기 때문에 중요한 문서가 나중에 인쇄될 수 있습니다. 이런 문제를 보완하기 위해 중요도가 높은 문서를 먼저 인쇄하는 프린터를 개발했습니다. 이 새롭게 개발한 프린터는 아래와 같은 방식으로 인쇄 작업을 수행합니다.

# %% [markdown]
# 1. 인쇄 대기목록의 가장 앞에 있는 문서(J)를 대기목록에서 꺼냅니다.
# 2. 나머지 인쇄 대기목록에서 J보다 중요도가 높은 문서가 한 개라도 존재하면 J를 대기목록의 가장 마지막에 넣습니다.
# 3. 그렇지 않으면 J를 인쇄합니다.

# %% [markdown]
# 예를 들어, 4개의 문서(A, B, C, D)가 순서대로 인쇄 대기목록에 있고 중요도가 2 1 3 2 라면 C D A B 순으로 인쇄하게 됩니다.
#
# 내가 인쇄를 요청한 문서가 몇 번째로 인쇄되는지 알고 싶습니다. 위의 예에서 C는 1번째로, A는 3번째로 인쇄됩니다.
#
# 현재 대기목록에 있는 문서의 중요도가 순서대로 담긴 배열 priorities와 내가 인쇄를 요청한 문서가 현재 대기목록의 어떤 위치에 있는지를 알려주는 location이 매개변수로 주어질 때, 내가 인쇄를 요청한 문서가 몇 번째로 인쇄되는지 return 하도록 solution 함수를 작성해주세요.

# %% [markdown]
# ### 제한사항
# 현재 대기목록에는 1개 이상 100개 이하의 문서가 있습니다.
# 인쇄 작업의 중요도는 1~9로 표현하며 숫자가 클수록 중요하다는 뜻입니다.
# location은 0 이상 (현재 대기목록에 있는 작업 수 - 1) 이하의 값을 가지며 대기목록의 가장 앞에 있으면 0, 두 번째에 있으면 1로 표현합니다.

# %% [markdown]
# ### 입출력 예 설명
# 예제 #1
#
# 문제에 나온 예와 같습니다.
#
# 예제 #2
#
# 6개의 문서(A, B, C, D, E, F)가 인쇄 대기목록에 있고 중요도가 1 1 9 1 1 1 이므로 C D E F A B 순으로 인쇄합니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1차 시도

# %%
# 1차시도
import queue
def solution(priorities, location):
    answer = 0
    ck = 0
    # 해당 인덱스 확인
    stop = -1
    while stop != 0:
        for j in range(len(priorities)):
            #  대기열에 자신보다 큰 수가 없을 경우 출력(location)
            if priorities[0] == priorities[location] and priorities[0] > priorities[j]:
                answer += 1
                stop = 0
                del priorities[0]
                break

            #  자신보다 큰 수가 있을 경우 대기열 이동(location)
            elif priorities[0] == priorities[location] and priorities[0] < priorities[j]:
                answer += 1
                location -= 1
                ck = 0
                priorities.append(priorities[0])
                del priorities[0]
                break
            
            # 대기열에 자신보다 큰 수가 없을 경우 출력(일반)
            elif priorities[0] >= priorities[j]:
                ck += 1
                if ck == 4:
                    ck = 0
                    del priorities[0]
                    break
                        
            # 우선 순위가 작을 경우 대기열 이동
            else:
                priorities.append(priorities[0])
                location -= 1
                ck = 0
                del priorities[0]
                break

    return answer

priorities = [1, 1, 9, 1, 1, 1]
location = 0
print(solution(priorities, location))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19320/1526545263.py in <module>
#      44 priorities = [1, 1, 9, 1, 1, 1]
#      45 location = 0
# ---> 46 print(solution(priorities, location))
#
# ~\AppData\Local\Temp/ipykernel_19320/1526545263.py in solution(priorities, location)
#       9         for j in range(len(priorities)):
#      10             #  대기열에 자신보다 큰 수가 없을 경우 출력(location)
# ---> 11             if priorities[0] == priorities[location] and priorities[0] > priorities[j]:
#      12                 answer += 1
#      13                 stop = 0
#
# IndexError: list index out of range

# %%
# 2차 시도
def solution(priorities, location):
    answer = 0
    cnt = 0
    stop = 0

    # 출력물 인덱스 저장
    a = [number for number in range(len(priorities))]

    # 중요도 탐색
    while True:

        # 중요도 사전 탐색
        for i in range(1, len(priorities)):
            if priorities[0] < priorities[i]:
                stop = 1

        # 중요도 탐색 순환 - location
        if a[0] == location and stop == 1:
            priorities.append(priorities[0])
            del priorities[0]
            a.append(a[0])
            del a[0]
            stop = 0

        # 중요도 탐색 순환 - general
        elif stop == 1:
            priorities.append(priorities[0])
            del priorities[0]
            a.append(a[0])
            del a[0]
            stop = 0      

        # location 출력시
        elif a[0] == location and stop == 0:
            cnt += 1
            answer = cnt
            break

        # general 출력시
        elif stop == 0:
            del priorities[0]
            del a[0]
            cnt += 1

    return answer

priorities = [2, 1, 3, 2]
location = 2
print(solution(priorities, location))
# Out:
# 1

# %% [markdown]
# ![image.png](attachment:image.png)
